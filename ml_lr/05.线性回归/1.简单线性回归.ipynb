# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1.,2.,3.,4.,5.])
y = np.array([1.,3.,2.,3.,5.])

# %%
plt.scatter(x,y)
plt.axis([0,6,0,6])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0
d = 0.0
for x_i, y_i in zip(x,y):
    num += (x_i - x_mean) * (y_i - y_mean)
    d += (x_i - x_mean) **2

# %%
a = num/d
b = y_mean - a*x_mean

# %%
a
# Out:
# 0.8

# %%
b
# Out:
# 0.39999999999999947

# %%
y_hat = a * x + b

# %%
plt.scatter(x,y)
plt.plot(x, y_hat, color= 'r')
plt.axis([0,6,0,6])
plt.show()

# %%
x_predict = 6
y_predict = a * x_predict + b

# %%
y_predict
# Out:
# 5.2

# %% [markdown]
# ### 使用我们自己的SimpleLinearRegression

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression1

reg1 = SimpleLinearRegression1()
reg1.fit(x,y)

# %%
reg1.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
reg1.a
# Out:
# 0.8

# %%
reg1.b
# Out:
# 0.39999999999999947

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color="r")
plt.axis([0,6,0,6])
plt.show()

# %% [markdown]
# ### 向量化实现SimpleLinearRegression

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression2

reg2 = SimpleLinearRegression2()
reg2.fit(x,y)

# %%
reg2.a
# Out:
# 0.8

# %%
reg2.b
# Out:
# 0.39999999999999947

# %%
y_hat2 = reg2.predict(x)

plt.scatter(x, y)
plt.plot(x, y_hat2, color="r")
plt.axis([0,6,0,6])
plt.show()

# %% [markdown]
# ### 向量化实现的性能测试

# %%
m = 100000
big_x = np.random.random(size=m)
big_y = big_x * 2.0 +3.0 + np.random.normal(size=m)

# %%
# %timeit reg1.fit(big_x,big_y)
# %timeit reg2.fit(big_x,big_y)
# Out:
# 115 ms ± 2.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.17 ms ± 34.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
reg1.a
# Out:
# 2.011793418682851

# %%
reg1.b
# Out:
# 2.990296933269317

# %%
reg2.a
# Out:
# 2.011793418682845

# %%
reg2.b
# Out:
# 2.9902969332693194
